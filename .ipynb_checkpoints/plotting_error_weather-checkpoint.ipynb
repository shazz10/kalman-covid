# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
t = pd.read_csv("prediction.csv")
t.tail(5)
# Out:
#             date             region  confirmed  1_day_change  3_day_change  \
# 2536  2020-04-11  India_West Bengal        126            13            25
# 2537  2020-04-12  India_West Bengal        134            10            27
# 2538  2020-04-13  India_West Bengal        152             8            31
# 2539  2020-04-14  India_West Bengal        190            18            36
# 2540  2020-04-15  India_West Bengal          0            38            64
#
#       7_day_change  1_day_change_rate  3_day_change_rate  7_day_change_rate  \
# 2536            53          12.621359          27.472527          84.126984
# 2537            57           8.620690          27.272727          82.608696
# 2538            54           6.349206          30.097087          67.500000
# 2539            72          13.432836          31.034483          90.000000
# 2540            99          25.000000          50.793651         108.791209
#
#       last_day  kalman_prediction
# 2536       116              122.0
# 2537       126              132.0
# 2538       134              142.0
# 2539       152              157.0
# 2540       190              187.0

# %%
ts = pd.read_csv("ts_r_9may.csv")
ts.tail(5)
# Out:
#      Unnamed: 0        date  India_Andaman and Nicobar Islands  \
# 96           96  2020-05-05                                 33
# 97           97  2020-05-06                                 33
# 98           98  2020-05-07                                 33
# 99           99  2020-05-08                                 33
# 100         100  2020-05-09                                 33
#
#      India_Andhra Pradesh  India_Arunachal Pradesh  India_Assam  India_Bihar  \
# 96                   1717                        1           43          529
# 97                   1717                        1           43          536
# 98                   1777                        1           45          542
# 99                   1847                        1           54          550
# 100                  1887                        1           59          571
#
#      India_Chandigarh  India_Chhattisgarh  India_Dadar Nagar Haveli  ...  \
# 96                102                  58                         0  ...
# 97                111                  59                         1  ...
# 98                120                  59                         1  ...
# 99                135                  59                         1  ...
# 100               150                  59                         1  ...
#
#      India_Odisha  India_Puducherry  India_Punjab  India_Rajasthan  \
# 96            170                 9          1233             3061
# 97            175                 9          1451             3158
# 98            185                 9          1516             3317
# 99            219                 9          1644             3427
# 100           271                 9          1731             3579
#
#      India_Tamil Nadu  India_Telengana  India_Tripura  India_Uttar Pradesh  \
# 96               3550             1085             29                 2859
# 97               4058             1096             43                 2880
# 98               4829             1107             43                 2998
# 99               5409             1123             65                 3071
# 100              6009             1133            118                 3214
#
#      India_Uttarakhand  India_West Bengal
# 96                  60               1259
# 97                  61               1344
# 98                  61               1456
# 99                  61               1548
# 100                 63               1678
#
# [5 rows x 36 columns]

# %%
ts.columns
# Out:
# Index(['Unnamed: 0', 'date', 'India_Andaman and Nicobar Islands',
#        'India_Andhra Pradesh', 'India_Arunachal Pradesh', 'India_Assam',
#        'India_Bihar', 'India_Chandigarh', 'India_Chhattisgarh',
#        'India_Dadar Nagar Haveli', 'India_Delhi', 'India_Goa', 'India_Gujarat',
#        'India_Haryana', 'India_Himachal Pradesh', 'India_Jammu and Kashmir',
#        'India_Jharkhand', 'India_Karnataka', 'India_Kerala', 'India_Ladakh',
#        'India_Madhya Pradesh', 'India_Maharashtra', 'India_Manipur',
#        'India_Meghalaya', 'India_Mizoram', 'India_Nagaland', 'India_Odisha',
#        'India_Puducherry', 'India_Punjab', 'India_Rajasthan',
#        'India_Tamil Nadu', 'India_Telengana', 'India_Tripura',
#        'India_Uttar Pradesh', 'India_Uttarakhand', 'India_West Bengal'],
#       dtype='object')

# %%
regions=['date','India_Andhra Pradesh', 'India_Delhi', 'India_Gujarat',
        'India_Haryana', 'India_Jammu and Kashmir', 'India_Karnataka',
        'India_Kerala', 'India_Madhya Pradesh', 'India_Maharashtra',
        'India_Punjab', 'India_Rajasthan', 'India_Tamil Nadu',
        'India_Telengana', 'India_Uttar Pradesh', 'India_West Bengal']

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
#p=ts[regions]
p=ts[["date","India_nan"]]
p = p.rename(columns={"India_nan":"India"})
p = p.set_index("date")
p.iloc[:,:].plot(marker='*',x_compat=True,figsize=(15,10)).set_title('Confirmed Cases - India',fontdict={'fontsize': 22})
fig = plt.gcf()
fig.savefig("Confirmed_Cases_India"+".png")

# %%
new=prediction.loc[prediction["region"]==region][["date","X"]]
new["Confirmed_Cases"] = p["Confirmed_Cases"]
#new=new.set_index(["date"])
new = new.reset_index(drop=True)
new["X"]=round(new["X"])
new = new.rename(columns={"X":"Kalman Prediction"})
new
# Out:
#           date  Kalman Prediction  Confirmed_Cases
# 0   2020-03-01                0.0                0
# 1   2020-03-02                3.0                0
# 2   2020-03-03                7.0                0
# 3   2020-03-04                6.0                0
# 4   2020-03-05               29.0                0
# 5   2020-03-06               37.0                0
# 6   2020-03-07               41.0                0
# 7   2020-03-08               43.0                0
# 8   2020-03-09               46.0                0
# 9   2020-03-10               49.0                0
# 10  2020-03-11               58.0                0
# 11  2020-03-12               66.0                0
# 12  2020-03-13               77.0                0
# 13  2020-03-14               87.0                0
# 14  2020-03-15              104.0                0
# 15  2020-03-16              120.0                0
# 16  2020-03-17              131.0                0
# 17  2020-03-18              149.0                0
# 18  2020-03-19              166.0                0
# 19  2020-03-20              197.0                0
# 20  2020-03-21              244.0                0
# 21  2020-03-22              322.0                0
# 22  2020-03-23              405.0                0
# 23  2020-03-24              512.0                0
# 24  2020-03-25              589.0                0
# 25  2020-03-26              697.0                0
# 26  2020-03-27              791.0                0
# 27  2020-03-28              931.0                0
# 28  2020-03-29             1060.0                0
# 29  2020-03-30             1141.0                0
# 30  2020-03-31             1306.0                0
# 31  2020-04-01             1476.0                0
# 32  2020-04-02             1925.0                0
# 33  2020-04-03             2510.0                0
# 34  2020-04-04             2841.0                0
# 35  2020-04-05             3293.0                0
# 36  2020-04-06             3814.0                0
# 37  2020-04-07             4792.0                0
# 38  2020-04-08             5637.0                0
# 39  2020-04-09             6411.0                0
# 40  2020-04-10             7247.0                0
# 41  2020-04-11             8153.0                0
# 42  2020-04-12             9074.0                0
# 43  2020-04-13             9939.0                0
# 44  2020-04-14            11059.0                0
# 45  2020-04-15            12202.0                0
# 46  2020-04-16            12703.0                0
# 47  2020-04-17            13273.0                0
# 48  2020-04-18            13540.0                1
# 49  2020-04-19            13868.0                1
# 50  2020-04-20            14178.0                2
# 51  2020-04-21            14567.0                3
# 52  2020-04-22            14686.0                4

# %%
for i in range(p.shape[0]):
    new.loc[i,"Confirmed_Cases"]=p.iloc[i]["Confirmed_Cases"]

# %%
new = new.set_index(["date"])

# %%
new
# Out:
#             Kalman Prediction  Confirmed_Cases
# date
# 2020-01-30                0.0              1.0
# 2020-01-31                1.0              1.0
# 2020-02-01                1.0              2.0
# 2020-02-02                2.0              3.0
# 2020-02-03                3.0              3.0
# ...                       ...              ...
# 2020-04-17              388.0              NaN
# 2020-04-18              399.0              NaN
# 2020-04-19              409.0              NaN
# 2020-04-20              413.0              NaN
# 2020-04-21              415.0              NaN
#
# [83 rows x 2 columns]

# %%
new.plot(marker='o',figsize=(16,8)).set_title("7 day prediction of "+region.split("_")[1])
plt.text(10,100,"hi trger")
# Out:
# Text(10, 100, 'hi trger')

# %%
pred=np.array(new.loc[new["date"]>="2020-04-15"].iloc[:,0])
pred
# Out:
# array(['2020-04-15', '2020-04-16', '2020-04-17', '2020-04-18',
#        '2020-04-19', '2020-04-20', '2020-04-21'], dtype=object)

# %%
evaluation=[]
pred=np.array(new.loc[new["date"]>="2020-04-15"].iloc[:,0])
ex=np.array(new.iloc[:,1])
evaluation.append({'region': region,
                              'mse': np.power((ex - pred),2).mean(),
                              'rmse':sqrt(mean_squared_error(ex,pred)),
                              'mae': (abs(ex - pred)).mean()})
print(evaluation)
# Out:
# [{'region': 'India_West Bengal', 'mse': 443.67469879518075, 'rmse': 21.06358703533614, 'mae': 6.879518072289157}]

# %%
plt.rcParams.update({'font.size': 22})

# %%
prediction = pd.read_csv("15daypred24apr.csv")
prediction
# Out:
#                                  region        date    Y           X       X2
# 0     India_Andaman and Nicobar Islands  2020-01-30    0    0.000000   0.0000
# 1     India_Andaman and Nicobar Islands  2020-01-31    0    0.000000   0.0000
# 2     India_Andaman and Nicobar Islands  2020-02-01    0    0.000000   0.0000
# 3     India_Andaman and Nicobar Islands  2020-02-02    0    0.000000   0.0000
# 4     India_Andaman and Nicobar Islands  2020-02-03    0    0.000000   0.0000
# ...                                 ...         ...  ...         ...      ...
# 3429                  India_West Bengal  2020-05-05  651  629.511687  25.9771
# 3430                  India_West Bengal  2020-05-06  651  654.457611  33.0208
# 3431                  India_West Bengal  2020-05-07  651  667.183972  31.8875
# 3432                  India_West Bengal  2020-05-08  651  671.549381  26.5825
# 3433                  India_West Bengal  2020-05-09    0  670.834522  19.8466
#
# [3434 rows x 5 columns]

# %% [markdown]
# # Main Code Below

# %%
#main code to plot and error calculation

regions=['India_Andhra Pradesh', 'India_Delhi', 'India_Gujarat',
       'India_Haryana', 'India_Jammu and Kashmir', 'India_Karnataka',
       'India_Kerala', 'India_Madhya Pradesh', 'India_Maharashtra',
       'India_Punjab', 'India_Rajasthan', 'India_Tamil Nadu',
       'India_Telengana', 'India_Uttar Pradesh', 'India_West Bengal']
#regions = ["India_nan"]
evaluation=[]

for region in regions:
    p=ts[['date',region]]
    p=p.rename(columns={region:"Confirmed_Cases"})
    
    new=prediction.loc[prediction["region"]==region][["date","X"]]
    new["Confirmed_Cases"] = p["Confirmed_Cases"]
    #new=new.set_index(["date"])
    new = new.reset_index(drop=True)
    new["X"]=round(new["X"])
    new = new.rename(columns={"X":"Kalman Prediction"})
    for i in range(p.shape[0]):
        new.loc[i,"Confirmed_Cases"]=p.iloc[i]["Confirmed_Cases"]  
    pred=np.array(new.loc[new["date"]>="2020-04-25"].iloc[:,1])
    ex=np.array(new.loc[new["date"]>="2020-04-25"].iloc[:,2])
    evaluation.append({'region': region,'mae': (abs(ex - pred)).mean()})
    new = new.set_index(["date"])
    fig = new.plot(marker='o',figsize=(20,10)).set_title("15 day prediction from 24/04/20 of "+region.split("_")[1])
    #plt.text(10,200,"Prediction Done for 15/04 to 21/04 on training data till 14/04 \n Metric Error Results: MSE: {}   RMSE: {}   MAE: {} ".format(evaluation["mse"],evaluation['rmse'],evaluation["mae"]))
    fig = plt.gcf()
    fig.savefig("15day/"+region.split("_")[1]+".png")

# %%
evaluation
# Out:
# [{'region': 'India_Andhra Pradesh', 'mae': 55.333333333333336},
#  {'region': 'India_Delhi', 'mae': 1599.2666666666667},
#  {'region': 'India_Gujarat', 'mae': 195.46666666666667},
#  {'region': 'India_Haryana', 'mae': 68.26666666666667},
#  {'region': 'India_Jammu and Kashmir', 'mae': 131.6},
#  {'region': 'India_Karnataka', 'mae': 38.8},
#  {'region': 'India_Kerala', 'mae': 38.8},
#  {'region': 'India_Madhya Pradesh', 'mae': 162.2},
#  {'region': 'India_Maharashtra', 'mae': 3527.0666666666666},
#  {'region': 'India_Punjab', 'mae': 440.8},
#  {'region': 'India_Rajasthan', 'mae': 340.93333333333334},
#  {'region': 'India_Tamil Nadu', 'mae': 1214.2},
#  {'region': 'India_Telengana', 'mae': 145.26666666666668},
#  {'region': 'India_Uttar Pradesh', 'mae': 245.4},
#  {'region': 'India_West Bengal', 'mae': 375.2}]

# %%
from fpdf import FPDF
import glob
import cv2

# %%
from PIL import Image
im_list = []
for file in glob.glob("*.png"):
    im=Image.open(file)
    rgb = Image.new('RGB', im.size, (255, 255, 255))  # white background
    rgb.paste(im, mask=im.split()[3])  
    im_list.append(rgb)

# %%
pdf1_filename = "30daypredictsfrom21APRIL.pdf"

im_list[0].save(pdf1_filename, "PDF" ,resolution=100.0, save_all=True, append_images=im_list[1:])

# %%
regions=['India_Andhra Pradesh', 'India_Delhi', 'India_Gujarat',
       'India_Haryana', 'India_Jammu and Kashmir', 'India_Karnataka',
       'India_Kerala', 'India_Madhya Pradesh', 'India_Maharashtra',
       'India_Punjab', 'India_Rajasthan', 'India_Tamil Nadu',
       'India_Telengana', 'India_Uttar Pradesh', 'India_West Bengal']

# %%
import pandas as pd

# %%
mapping={}
for i in list(pd.read_csv("ts_r.csv").columns):
    mapping[i]=""

# %%
del mapping["date"]

# %%
mapping = {'India_Andhra Pradesh': 'Vishakhapatnam',
 'India_Delhi': 'New+Delhi',
 'India_Gujarat': 'Ahmedabad',
 'India_Haryana': 'Chandigarh',
 'India_Jammu and Kashmir': 'Srinagar',
 'India_Karnataka': 'Bengaluru',
 'India_Kerala': 'Thiruvananthapuram',
 'India_Madhya Pradesh': 'Indore',
 'India_Maharashtra': 'Mumbai',
 'India_Punjab': 'Chandigarh',
 'India_Rajasthan': 'Jaipur',
 'India_Tamil Nadu': 'Chennai',
 'India_Telengana': 'Hyderabad',
 'India_Uttar Pradesh': 'Lucknow',
 'India_West Bengal': 'Kolkata'}

# %%
mapping
# Out:
# {'India_Andhra Pradesh': 'Vishakhapatnam',
#  'India_Delhi': 'New+Delhi',
#  'India_Gujarat': 'Ahmedabad',
#  'India_Haryana': 'Chandigarh',
#  'India_Jammu and Kashmir': 'Srinagar',
#  'India_Karnataka': 'Bengaluru',
#  'India_Kerala': 'Thiruvananthapuram',
#  'India_Madhya Pradesh': 'Indore',
#  'India_Maharashtra': 'Mumbai',
#  'India_Punjab': 'Chandigarh',
#  'India_Rajasthan': 'Jaipur',
#  'India_Tamil Nadu': 'Chennai',
#  'India_Telengana': 'Hyderabad',
#  'India_Uttar Pradesh': 'Lucknow',
#  'India_West Bengal': 'Kolkata'}

# %%
city = list(mapping.values())

# %%
city
# Out:
# ['Vishakhapatnam',
#  'New+Delhi',
#  'Ahmedabad',
#  'Chandigarh',
#  'Srinagar',
#  'Bengaluru',
#  'Thiruvananthapuram',
#  'Indore',
#  'Mumbai',
#  'Chandigarh',
#  'Jaipur',
#  'Chennai',
#  'Hyderabad',
#  'Lucknow',
#  'Kolkata']

# %%
from wwo_hist import retrieve_hist_data

# %%
#get weather data
    
frequency = 24
start_date = '30-JAN-2020'
end_date = '09-MAY-2020'
api_key = '08006ae11aca415f9cb103546202104'
location_list = city
hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Vishakhapatnam
#
#
# Currently retrieving data for Vishakhapatnam: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.692806
# Currently retrieving data for Vishakhapatnam: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.861910
# Currently retrieving data for Vishakhapatnam: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.735825
# Currently retrieving data for Vishakhapatnam: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:08.227645
# Currently retrieving data for Vishakhapatnam: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:09.278344
#
#
# export Vishakhapatnam completed!
#
#
#
#
# Retrieving weather data for New+Delhi
#
#
# Currently retrieving data for New+Delhi: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.176149
# Currently retrieving data for New+Delhi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.949098
# Currently retrieving data for New+Delhi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.588785
# Currently retrieving data for New+Delhi: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.314003
# Currently retrieving data for New+Delhi: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:07.352862
#
#
# export New+Delhi completed!
#
#
#
#
# Retrieving weather data for Ahmedabad
#
#
# Currently retrieving data for Ahmedabad: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.751276
# Currently retrieving data for Ahmedabad: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.428999
# Currently retrieving data for Ahmedabad: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.850058
# Currently retrieving data for Ahmedabad: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.425969
# Currently retrieving data for Ahmedabad: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:08.609686
#
#
# export Ahmedabad completed!
#
#
#
#
# Retrieving weather data for Chandigarh
#
#
# Currently retrieving data for Chandigarh: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.212459
# Currently retrieving data for Chandigarh: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.722184
# Currently retrieving data for Chandigarh: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.398519
# Currently retrieving data for Chandigarh: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.887030
# Currently retrieving data for Chandigarh: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:09.077534
#
#
# export Chandigarh completed!
#
#
#
#
# Retrieving weather data for Srinagar
#
#
# Currently retrieving data for Srinagar: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.050613
# Currently retrieving data for Srinagar: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.634835
# Currently retrieving data for Srinagar: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.175102
# Currently retrieving data for Srinagar: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.599531
# Currently retrieving data for Srinagar: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:08.417193
#
#
# export Srinagar completed!
#
#
#
#
# Retrieving weather data for Bengaluru
#
#
# Currently retrieving data for Bengaluru: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.300237
# Currently retrieving data for Bengaluru: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.756323
# Currently retrieving data for Bengaluru: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.950074
# Currently retrieving data for Bengaluru: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.758143
# Currently retrieving data for Bengaluru: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:09.772415
#
#
# export Bengaluru completed!
#
#
#
#
# Retrieving weather data for Thiruvananthapuram
#
#
# Currently retrieving data for Thiruvananthapuram: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.074389
# Currently retrieving data for Thiruvananthapuram: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.101222
# Currently retrieving data for Thiruvananthapuram: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.569097
# Currently retrieving data for Thiruvananthapuram: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.521953
# Currently retrieving data for Thiruvananthapuram: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:08.788844
#
#
# export Thiruvananthapuram completed!
#
#
#
#
# Retrieving weather data for Indore
#
#
# Currently retrieving data for Indore: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.894777
# Currently retrieving data for Indore: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.451700
# Currently retrieving data for Indore: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.145154
# Currently retrieving data for Indore: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.028801
# Currently retrieving data for Indore: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:06.940948
#
#
# export Indore completed!
#
#
#
#
# Retrieving weather data for Mumbai
#
#
# Currently retrieving data for Mumbai: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.120776
# Currently retrieving data for Mumbai: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.501004
# Currently retrieving data for Mumbai: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.226996
# Currently retrieving data for Mumbai: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.777258
# Currently retrieving data for Mumbai: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:08.629726
#
#
# export Mumbai completed!
#
#
#
#
# Retrieving weather data for Chandigarh
#
#
# Currently retrieving data for Chandigarh: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.089770
# Currently retrieving data for Chandigarh: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.961581
# Currently retrieving data for Chandigarh: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.765638
# Currently retrieving data for Chandigarh: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.682447
# Currently retrieving data for Chandigarh: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:08.788634
#
#
# export Chandigarh completed!
#
#
#
#
# Retrieving weather data for Jaipur
#
#
# Currently retrieving data for Jaipur: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.836819
# Currently retrieving data for Jaipur: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.253515
# Currently retrieving data for Jaipur: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.043737
# Currently retrieving data for Jaipur: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.960148
# Currently retrieving data for Jaipur: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:07.156223
#
#
# export Jaipur completed!
#
#
#
#
# Retrieving weather data for Chennai
#
#
# Currently retrieving data for Chennai: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.053324
# Currently retrieving data for Chennai: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.670969
# Currently retrieving data for Chennai: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.423243
# Currently retrieving data for Chennai: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.869428
# Currently retrieving data for Chennai: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:06.985985
#
#
# export Chennai completed!
#
#
#
#
# Retrieving weather data for Hyderabad
#
#
# Currently retrieving data for Hyderabad: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.298387
# Currently retrieving data for Hyderabad: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.649755
# Currently retrieving data for Hyderabad: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.809194
# Currently retrieving data for Hyderabad: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.248266
# Currently retrieving data for Hyderabad: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:08.575548
#
#
# export Hyderabad completed!
#
#
#
#
# Retrieving weather data for Lucknow
#
#
# Currently retrieving data for Lucknow: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.106950
# Currently retrieving data for Lucknow: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.754009
# Currently retrieving data for Lucknow: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.045839
# Currently retrieving data for Lucknow: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:07.406789
# Currently retrieving data for Lucknow: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:08.714095
#
#
# export Lucknow completed!
#
#
#
#
# Retrieving weather data for Kolkata
#
#
# Currently retrieving data for Kolkata: from 2020-01-30 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.000366
# Currently retrieving data for Kolkata: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:04.074725
# Currently retrieving data for Kolkata: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.786208
# Currently retrieving data for Kolkata: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:08.400946
# Currently retrieving data for Kolkata: from 2020-05-01 to 2020-05-09
# Time elapsed (hh:mm:ss.ms) 0:00:09.914275
#
#
# export Kolkata completed!

# %%
df = pd.DataFrame([])

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for region in mapping:
    print(mapping[region])
    df = pd.read_csv(mapping[region]+".csv")
    df['region'] = region
    data=data.append(df)
# Out:
# Vishakhapatnam
# New+Delhi
# Ahmedabad
# Chandigarh
# Srinagar
# Bengaluru
# Thiruvananthapuram
# Indore
# Mumbai
# Chandigarh
# Jaipur
# Chennai
# Hyderabad
# Lucknow
# Kolkata

# %%
data.to_csv("weather.csv",index=False)
